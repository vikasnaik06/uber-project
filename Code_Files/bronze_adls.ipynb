# %%
import pandas as pd

files = [
{"file": "map_cities"},
{"file":"map_cancellation_reasons"},
{"file":"map_payment_methods"},
{"file":"map_ride_statuses"},
{"file":"map_vehicle_makes"},
{"file":"map_vehicle_types"}
]

for file in files:
  url=f"https://dluberprojectvikas.blob.core.windows.net/raw/ingestion/{file['file']}.json?<your-token>"

  df = pd.read_json(url)
  df_spark = spark.createDataFrame(df)
    
    # Writing Data To the Bronze Layer
  df_spark.write.format("delta")\
            .mode("overwrite")\
            .option("overwriteSchema", "true")\
            .saveAsTable(f"uber.bronze.{file['file']}")

# %%
  url=f"https://dluberprojectvikas.blob.core.windows.net/raw/ingestion/bulk_rides.json?<your-token>"

df = pd.read_json(url)
df_spark = spark.createDataFrame(df)
if not spark.catalog.tableExists("uber.bronze.bulk_rides"):
    df_spark.write.format("delta")\
            .mode("overwrite")\
            .saveAsTable(f"uber.bronze.bulk_rides")
    print("This will not run more than 1 time")

# %%
# %sql
SELECT * FROM uber.bronze.rides_raw
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>value</th><th>topic</th><th>partition</th><th>offset</th><th>timestamp</th><th>timestampType</th><th>rides</th></tr></thead><tbody><tr><td>null</td><td>...</td><td>ubertopic</td><td>0</td><td>4</td><td>2026-03-29T10:55:34.951Z</td><td>0</td><td>{"ride_id": "35483e95-2bb4-43bf-9b03-e7e8467fd077", "confirmation_number": "Gw6-2519-Pd38", "passenger_id": "6407d528-c7f4-4dd5-8c26-81c2d123d1a3", "driver_id": "43c9d9c6-e34e-4c38-8914-fb092d0f1027", "vehicle_id": "f24d3ec6-af4b-4761-892a-2d02c415c501", "pickup_location_id": "d600740c-cd74-4607-ad9c-b010f02801d4", "dropoff_location_id": "3f40ad46-5ff2-41c6-a63a-2e89b5e0fef5", "vehicle_type_id": 4, "vehicle_make_id": 6, "payment_method_id": 3, "ride_status_id": 1, "pickup_city_id": 1, "dropoff_city_id": 10, "cancellation_reason_id": 4, "passenger_name": "Olivia Cannon", "passenger_email": "rnorton@example.net", "passenger_phone": "(378)259-7265x738", "driver_name": "Kristi Robertson", "driver_rating": 4.57, "driver_phone": "585.898.9301x6441", "driver_license": "pO-VVz-4054880", "vehicle_model": "Sure", "vehicle_color": "Red", "license_plate": "erP-4697", "pickup_address": "869 Tina Corners Apt. 675, Williamston, VA 39208", "pickup_latitude": 71.529088, "pickup_longitude": -55.330302, "dropoff_address": "9685 Alicia Fall Suite 812, Hernandezhaven, TX 81534", "dropoff_latitude": -55.309077, "dropoff_longitude": -50.803135, "distance_miles": 47.62, "duration_minutes": 14, "booking_timestamp": "2026-03-17T20:45:34.618086", "pickup_timestamp": "2026-03-17T20:55:34.618086", "dropoff_timestamp": "2026-03-17T21:09:34.618086", "base_fare": 2.5, "distance_fare": 83.33, "time_fare": 4.9, "surge_multiplier": 1.5, "subtotal": 136.09, "tip_amount": 0, "total_fare": 136.09, "rating": null}</td></tr><tr><td>null</td><td>...</td><td>ubertopic</td><td>0</td><td>5</td><td>2026-03-29T10:55:48.781Z</td><td>0</td><td>{"ride_id": "65d6c8ea-638b-48dd-8b60-46cd84dcb7b1", "confirmation_number": "qV4-8845-nY62", "passenger_id": "1a455792-c12e-4435-bb3a-5f2e259918bc", "driver_id": "561a9de4-d4eb-42f8-8cce-916f7e921bc7", "vehicle_id": "467d24ca-5cb1-487b-8ca3-cb086024bd20", "pickup_location_id": "6aaf4b7d-85e9-46f1-949b-a947a324059e", "dropoff_location_id": "c746ca07-384a-4dfc-964a-82a09bead853", "vehicle_type_id": 1, "vehicle_make_id": 1, "payment_method_id": 3, "ride_status_id": 1, "pickup_city_id": 5, "dropoff_city_id": 2, "cancellation_reason_id": 3, "passenger_name": "Sarah Wilson", "passenger_email": "natalie86@example.com", "passenger_phone": "+1-714-679-7850x9954", "driver_name": "William Howard", "driver_rating": 4.13, "driver_phone": "001-612-534-0878x7498", "driver_license": "uE-myO-4549758", "vehicle_model": "Form", "vehicle_color": "Black", "license_plate": "Frg-9462", "pickup_address": "9334 Anthony Prairie, North Michaeltown, MN 93580", "pickup_latitude": -32.742803, "pickup_longitude": -143.559329, "dropoff_address": "84431 Phelps Points, Gabriellabury, AS 17806", "dropoff_latitude": -23.801166, "dropoff_longitude": 39.469674, "distance_miles": 20.59, "duration_minutes": 111, "booking_timestamp": "2026-03-16T12:52:48.903510", "pickup_timestamp": "2026-03-16T12:55:48.903510", "dropoff_timestamp": "2026-03-16T14:46:48.903510", "base_fare": 2.5, "distance_fare": 36.03, "time_fare": 38.85, "surge_multiplier": 2.09, "subtotal": 161.72, "tip_amount": 8.44, "total_fare": 170.16, "rating": null}</td></tr><tr><td>null</td><td>...</td><td>ubertopic</td><td>0</td><td>6</td><td>2026-03-29T14:33:47.962Z</td><td>0</td><td>{"ride_id": "c17f66fe-a380-4f69-b05c-4708fbd041a1", "confirmation_number": "Bb9-7134-Ls09", "passenger_id": "a8237bee-51a8-4706-b729-de069f90b33e", "driver_id": "b44fb642-a64d-4c03-b5ea-0e90e9fa912c", "vehicle_id": "10a685b9-f94b-4d1e-93ea-5a438a435bfc", "pickup_location_id": "435cfaed-8aae-4c59-9555-5895557c6331", "dropoff_location_id": "44655675-7b17-498b-90ce-ba7 ...

# %%
# %sql
select * from uber.bronze.map_cities
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city_id</th><th>city</th><th>state</th><th>region</th><th>updated_at</th></tr></thead><tbody><tr><td>1</td><td>New York</td><td>NY</td><td>Northeast</td><td>2026-04-16T04:25:21.297Z</td></tr><tr><td>2</td><td>Los Angelas</td><td>CA</td><td>West</td><td>2026-04-16T04:25:21.297Z</td></tr><tr><td>3</td><td>Chicago</td><td>IL</td><td>Midwest</td><td>2026-04-16T04:25:21.297Z</td></tr><tr><td>4</td><td>Houston</td><td>TX</td><td>South</td><td>2026-04-16